# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import sys
import warnings
from pandas.errors import PerformanceWarning 
warnings.filterwarnings('ignore', category=PerformanceWarning)

root_path = '/home/jadli/Desktop/BDAI2/projects/Credit-risk/data/train_data'
sys.path.append(os.path.abspath("../.."))

from src.model import train_model
from src.data import clean_feature_names


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


# Charger les fichiers de données en utilisant le chemin racine
df_train = pd.read_csv(os.path.join(root_path, 'df_train_merged.csv'))
df_test = pd.read_csv(os.path.join(root_path, 'df_test_merged.csv'))

# %%
# Convertir les colonnes catégorielles en type 'category'
categorical_columns = [
    'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 
    'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 
    'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 
    'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE'
]

# Appliquer la conversion sur toutes les colonnes catégorielles
for col in categorical_columns:
    df_train[col] = df_train[col].astype('category')
    df_test[col] = df_test[col].astype('category')

# %%
results = train_model(clean_feature_names(df_train), clean_feature_names(df_test))
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=150, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=150
# [LightGBM] [Warning] min_data_in_leaf is set=150, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=150
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226148
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.122447 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 83765
# [LightGBM] [Info] Number of data points in the train set: 246008, number of used features: 792
# [LightGBM] [Warning] min_data_in_leaf is set=150, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=150
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432482
# [LightGBM] [Info] Start training from score -2.432482
# Training until validation scores don't improve for 600 rounds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = train_model(clean_feature_names(df_train), clean_feature_names(df_test))
#
# File ~/Desktop/BDAI2/projects/Credit-risk/src/model.py:51, in train_model(df_train, df_test)
#      34 # Modèle de classification
#      35 model = lgb.LGBMClassifier(
#      36     n_estimators=7000,
#      37     learning_rate=0.0005,
#    (...)     48     scale_pos_weight=scale_pos_weight
#      49 )
# ---> 51 model.fit(
#      52     X_train, y_train,
#      53     eval_set=[(X_valid, y_valid)],
#      54     eval_metric="auc",
#      55     callbacks=[lgb.early_stopping(600, verbose=True)]
#      56 )
#      57 results['auc_train'] = eval(model, X_train, y_train)
#      58 results['auc_val'] = eval(model, X_valid, y_valid)
#
# File ~/Desktop/BDAI2/projects/Credit-risk/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py:1560, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1557         else:
#    1558             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1560 super().fit(
#    1561     X,
#    1562     _y,
#    1563     sample_weight=sample_weight,
#    1564     init_score=init_score,
#    1565     eval_set=valid_sets,
#    1566     eval_names=eval_names,
#    1567     eval_sample_weight=eval_sample_weight,
#    1568     eval_class_weight=eval_class_weight,
#    1569     eval_init_score=eval_init_score,
#    1570     eval_metric=eval_metric,
#    1571     feature_name=feature_name,
#    1572     categorical_feature=categorical_feature,
#    1573     callbacks=callbacks,
#    1574     init_model=init_model,
#    1575 )
#    1576 return self
#
# File ~/Desktop/BDAI2/projects/Credit-risk/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~/Desktop/BDAI2/projects/Credit-risk/.venv/lib/python3.12/site-packages/lightgbm/engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File ~/Desktop/BDAI2/projects/Credit-risk/.venv/lib/python3.12/site-packages/lightgbm/basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:
